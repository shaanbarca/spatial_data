# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# * https://www.nomor.net/_kodepos.php?_i=kode-wilayah&asc=010&urut=2#Desa
# * https://www.indonesia-geospasial.com/2023/05/download-shapefile-batas-administrasi.html

# %%
fiona.drvsupport.supported_drivers['kml'] = 'rw' # enable KML support which is disabled by default
fiona.drvsupport.supported_drivers['KML'] = 'rw' # enable KML support which is disabled by default

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/shaanbarca/Desktop'

# %%
# df_places = gpd.read_file('Politic/Data/Dapil_PAD_Dukcapil_geom_final.geojson')
df_places = gpd.read_file('Politic/Updated_data/WADM DESA 2022 Update/Batas Wilayah Kel Desa 2022.shp')

# %%
df_places.columns
# Out:
# Index(['OBJECTID', 'NAMOBJ', 'FCODE', 'REMARK', 'METADATA', 'SRS_ID', 'KDBBPS',
#        'KDCBPS', 'KDCPUM', 'KDEBPS', 'KDEPUM', 'KDPBPS', 'KDPKAB', 'KDPPUM',
#        'LUASWH', 'TIPADM', 'WADMKC', 'WADMKD', 'WADMKK', 'WADMPR', 'WIADKC',
#        'WIADKK', 'WIADPR', 'WIADKD', 'UUPP', 'geometry'],
#       dtype='object')

# %%
df_places[['OBJECTID', 'NAMOBJ', 'FCODE', 'REMARK', 'METADATA', 'SRS_ID', 'KDBBPS',
       'KDCBPS', 'KDCPUM', 'KDEBPS', 'KDEPUM', 'KDPBPS', 'KDPKAB', 'KDPPUM',
       'LUASWH', 'TIPADM', 'WADMKC', 'WADMKD', 'WADMKK']]
# Out:
#        OBJECTID          NAMOBJ       FCODE  REMARK  \
# 0        1147.0      Banyuwangi  BA03070040    None
# 1        1148.0       Banyuwulu  BA03070040    None
# 2        1149.0       Banyuyoso  BA03070040    None
# 3        1150.0            Baok  BA03070040  <Null>
# 4        1151.0    Baosan Kidul  BA03070040    None
# ...         ...             ...         ...     ...
# 84242   63559.0  Paya Keureuleh  BA03070040    None
# 84243   63560.0  Paya Keutapang  BA03070040    None
# 84244   63561.0      Paya Kolak  BA03070040    None
# 84245   63562.0      Paya Kruep  BA03070040    None
# 84246   63563.0       Paya Kuda  BA03070040    None
#
#                                             METADATA     SRS_ID KDBBPS KDCBPS  \
# 0      TASWIL1000020201023_DATA_BATAS_DESA/KELURAHAN  SRGI 2013   None   None
# 1      TASWIL1000020201023_DATA_BATAS_DESA/KELURAHAN  SRGI 2013   None   None
# 2      TASWIL1000020201023_DATA_BATAS_DESA/KELURAHAN  SRGI 2013   None   None
# ...

# %%
df_places.isnull().sum()
# Out:
# OBJECTID        0
# NAMOBJ          5
# FCODE           0
# REMARK      67357
# METADATA        0
# SRS_ID          0
# KDBBPS      75829
# KDCBPS      75822
# KDCPUM         56
# KDEBPS      76158
# KDEPUM        121
# KDPBPS      75187
# KDPKAB          3
# KDPPUM          1
# LUASWH       2420
# TIPADM       4976
# WADMKC         73
# WADMKD          5
# WADMKK          2
# WADMPR          0
# WIADKC      77555
# WIADKK      76743
# WIADPR      77389
# WIADKD      61554
# UUPP           42
# geometry        0
# dtype: int64
